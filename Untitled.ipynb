# %%
def import_data(filename):
	data_df= pd.read_csv(filename)
	return data_df

# %%
import numpy as np
import pandas as pd

# %%
filename = "evaluation_data.csv"

# %%
df = import_data(filename)

# %%
df.iloc[3].term
# Out:
# ' 36 months'

# %%
df.iloc[:5,:10]
# Out:
#          id  loan_amnt        term int_rate  installment grade sub_grade  \
# 0  90531864       4500   36 months   12.79%       151.17     C        C1
# 1  90521796      25000   60 months   14.49%       588.08     C        C4
# 2  90270660       2000   36 months   13.49%        67.87     C        C2
# 3  90611738      20000   36 months    8.99%       635.91     B        B1
# 4  90692987      35000   60 months   15.59%       843.53     C        C5
#
#                       emp_title emp_length home_ownership
# 0                           NaN        n/a       MORTGAGE
# 1                           USA  10+ years       MORTGAGE
# 2  Training & Education Manager     1 year       MORTGAGE
# 3                           NaN        n/a       MORTGAGE
# 4    Vice president of culinary     1 year       MORTGAGE

# %%
df=df.dropna(axis=1)

# %%
df=df.drop("emp_length", axis=1)

# %%
df
# Out:
#             id  loan_amnt        term int_rate  installment grade sub_grade  \
# 0     90531864       4500   36 months   12.79%       151.17     C        C1
# 1     90521796      25000   60 months   14.49%       588.08     C        C4
# 2     90270660       2000   36 months   13.49%        67.87     C        C2
# 3     90611738      20000   36 months    8.99%       635.91     B        B1
# 4     90692987      35000   60 months   15.59%       843.53     C        C5
# 5     90211258      14850   60 months   18.99%       385.14     D        D3
# 6     90191117       2000   36 months   18.99%        73.31     D        D3
# 7     90611716       4000   36 months   10.99%       130.94     B        B4
# 8     90280064       1800   36 months   14.49%        61.95     C        C4
# 9     90591281       4800   36 months   15.59%       167.79     C        C5
# 10    90108929       3000   36 months   13.99%       102.52     C        C3
# ...

# %%
def export_data(df, filename):
	df.to_csv(filename, index=False, header=True)

# %%
export_data(df, "test.csv")

# %%
term_to_num = lambda x: int(x.replace(" months", ""))

# %%
df_new = df

# %%
df_new.term = list(map(term_to_num, list(df.term)))

# %%
def int_rate_to_num(df):
	f = lambda x: float(x.replace("%", ""))
	df.int_rate = list(map(f, list(df.int_rate)))
	return df

# %%
df_new = int_rate_to_num(df_new)

# %%
df_new.int_rate
# Out:
# 0       12.79
# 1       14.49
# 2       13.49
# 3        8.99
# 4       15.59
# 5       18.99
# 6       18.99
# 7       10.99
# 8       14.49
# 9       15.59
# 10      13.99
# 11       7.59
# 12      13.99
# 13      16.99
# 14      13.99
# 15       8.99
# 16       7.99
# 17      11.49
# 18      10.49
# 19      15.59
# 20      24.99
# 21      11.49
# 22      23.99
# 23      11.49
# 24      14.49
# 25      13.49
# 26      17.99
# 27      17.99
# 28       8.99
# 29      10.49
#         ...
# 6615    10.99
# 6616     8.99
# 6617    18.99
# 6618    10.99
# 6619    22.39
# 6620    10.49
# 6621    17.99
# 6622    12.79
# 6623     8.99
# 6624    15.59
# 6625    11.49
# 6626    16.99
# 6627    28.88
# 6628    10.49
# 6629    10.99
# 6630    10.49
# 6631    28.88
# 6632     8.59
# 6633    15.59
# 6634     8.99
# 6635     8.99
# 6636    21.49
# 6637     9.49
# 6638     9.49
# 6639     8.59
# 6640    16.99
# 6641    10.99
# 6642    10.49
# 6643    23.99
# 6644     7.89
# ...

# %%
df_new.loc[:, ["id", "term", "grade"]]
# Out:
#             id  term grade
# 0     90531864    36     C
# 1     90521796    60     C
# 2     90270660    36     C
# 3     90611738    36     B
# 4     90692987    60     C
# 5     90211258    60     D
# 6     90191117    36     D
# 7     90611716    36     B
# 8     90280064    36     C
# 9     90591281    36     C
# 10    90108929    36     C
# 11    90631697    36     A
# 12    89817247    60     C
# 13    90695712    36     D
# 14    90379558    60     C
# 15    90164623    36     B
# 16    90312085    36     A
# 17    90078228    36     B
# 18    89837832    36     B
# 19    90312543    60     C
# 20    90571484    60     E
# 21    90611373    36     B
# 22    90407033    36     E
# 23    88855464    36     B
# 24    90601237    36     C
# 25    89935364    36     C
# 26    90611298    36     D
# 27    90211482    36     D
# 28    90481163    36     B
# 29    90439579    36     B
# ...        ...   ...   ...
# 6615  84141109    36     B
# 6616  84052818    36     B
# ...

# %%
df_raw = import_data("evaluation_data.csv")

# %%
df_raw
# Out:
#             id  loan_amnt        term int_rate  installment grade sub_grade  \
# 0     90531864       4500   36 months   12.79%       151.17     C        C1
# 1     90521796      25000   60 months   14.49%       588.08     C        C4
# 2     90270660       2000   36 months   13.49%        67.87     C        C2
# 3     90611738      20000   36 months    8.99%       635.91     B        B1
# 4     90692987      35000   60 months   15.59%       843.53     C        C5
# 5     90211258      14850   60 months   18.99%       385.14     D        D3
# 6     90191117       2000   36 months   18.99%        73.31     D        D3
# 7     90611716       4000   36 months   10.99%       130.94     B        B4
# 8     90280064       1800   36 months   14.49%        61.95     C        C4
# 9     90591281       4800   36 months   15.59%       167.79     C        C5
# 10    90108929       3000   36 months   13.99%       102.52     C        C3
# ...

# %%
df_raw.iloc[:, 7].name
# Out:
# 'emp_title'

# %%
len(df_raw)
# Out:
# 6645

# %%
del_rate = 0.5
df_new = df_raw
for i in range(len(df_raw.columns)):
    attr = list(df_raw.iloc[:, i])
    name = df_raw.iloc[:, i].name
    count = 0
    for item in attr:
        if not item==item:
            count = count+1
    if(count>del_rate*len(df_raw)):
        print(name)
        print("del")
        df_new = df_raw.drop(name, axis=1)

# %%
len(df_new.columns)
# Out:
# 81
